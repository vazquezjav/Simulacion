# %% [markdown]
# <center><img src="https://pure.ups.edu.ec/skin/headerImage/" width="300" height="300"></center>

# %% [markdown]
# <h1><center>Universidad Politecnica Salesiana</center></h1>
# <h2><center>Simulacion Simpy Vacunas</center></h2>
#
#
# <b>Nombre: </b> Javier Vazquez
#
# <b>Materia: </b> Simulacion

# %%
import simpy
import random

# %% [markdown]
# ### Variables de Interes
#
# En este caso hemos decidido utilizar las siguientes variables de interes
# * <b>Mesas Vacunacion: </b> seran las mesas con las que cuenta el recinto para realizar el proceso de vacunacion
# * <b>Tiempo simulacion: </b>  tiempo que se tardara la simulacion
# * <b>Intervalo Llegada: </b> intervalo en la que se genera una nueva persona dentro de la simulacion
# * <b>Tiempo Vacunacion: </b> tiempo minimo que tarda en vacunar a una persona
# * <b>Tiempo espera sintomas: </b> tiempo de que espera una persona despues de ser vacunado para verificar que no tenga problemas de salud
# * <b>Tiempo certificado: </b>  tiempo minimo en entregar el certificado de vacunacion a la persona'
# * <b>Cola: </b> numero de personas generadas a que formen cola para recibir la vacuna
# * <b>Porcentaje proceso ecuador: </b> del total de la poblacion que existe en ecuador, porcentaje que se prevee asista al proceso de vacunacion
# * <b>Porcentaje no vacunar: </b>  porcentaje de las personas que acuden al proceso no pueden vacunarse por algun problema de salud
# * <b>Estado personas: </b>  guardar el estado de todas las personas(no proceso, cola, espera, vacunado, espera, carnet, no califica)
# * <b>Tiempos espera final: </b>  tiempo de espera cada persona en la cola hasta ser atendido por una mesa
# * <b>Tiempos vacunacion final: </b> tiempo en vacunarse cada persona
# * <b>Mesas libres vacunacion: </b> comprobar si una mesa se encuentra libre para aceptar nueva persona se vacune

# %%
MESAS_VACUNACION=4 
TIEMPO_SIMULACION=300
INTERVALO_LLEGADA=5
TIEMPO_VACUNACION=5
TIEMPO_ESPERAR_SINTOMAS=20
TIEMPO_CERTIFICADO=2
COLA=10
PORCENTAJE_PROCESO_ECUADOR=80 
PORCENTAJE_NO_VACUNAR=10
estado_personas={} 
tiempos_espera={} 
tiempo_vacunacion_final={} 
tiempo_espera_final={}
MESAS_LIBRES_VACUNACION={}

# %% [markdown]
# ### Variables Auxiliares
# * personas vacunacion
# * personas espera
# * personas carnet

# %%
personas_vacunacion={}
personas_espera={}
personas_carnet={}
for i in range(MESAS_VACUNACION):
    MESAS_LIBRES_VACUNACION[i]='Libre'

# %% [markdown]
# ### Desarrollo de clases
#
# Para esta simulacion unicamente se cuenta con la clase:
# * <b>Vacunacion </b> En la cual contiene los metodos respectivos a cada uno de la fases de la vacunacion como proceso vacunaciopn, comprobar si una mesa se encuentra libre, el proceso de esperar a posibles problemas de salud despues de recibir la vacuna y la entrega del carnet. <br>
# Cuando una persona pasa por cada uno de esos procesos automaticamente se van cambiando los estados en los cuales se encuentra la persona dentro del proceso de vacunacion

# %%
class Vacunacion(object):
    
    def __init__(self, environment, mesas_vacunacion):
        self.env= environment
        self.mesas_vacunacion = simpy.Resource(environment, mesas_vacunacion)
        
    def proceso_vacunacion(self, nombre, tiempo, idMesa):
        yield self.env.timeout(random.randint(tiempo, tiempo+5))
        estado_personas[nombre]='Vacunado'
        MESAS_LIBRES_VACUNACION[idMesa]='Libre'
        
    def mesas_libres_vacunacion(self, num_mesa):
        if MESAS_LIBRES_VACUNACION.get(num_mesa) =='Libre':
            return True
        else:
            return False
        
    def proceso_esperar(self,nombre, tiempo):
        yield self.env.timeout(tiempo)
        estado_personas[nombre]='Espera_sintomas'
    
    def entrega_carnet(self, nombre, tiempo):
        yield self.env.timeout(tiempo)
        estado_personas[nombre]='Carnet'

# %% [markdown]
# ### Desarrollo logica de la simulacion

# %%
def llegada_personas(env, nombre, vacunacion, tiempo_vacunacion, tiempo_espera, tiempo_certificado):
    
    if random.randint(1,100)>=(100-PORCENTAJE_PROCESO_ECUADOR):
        print('---> Genera [%s] a la cola hora %.2f.'%(nombre,env.now))
        if random.randint(1,100)<=PORCENTAJE_NO_VACUNAR:
            print('❌'*3,'[%s] acude al proceso pero no puede vacunarse  '%(nombre),'❌'*3)
            estado_personas[nombre]='No califica'
        else:
            estado_personas[nombre]='Cola'
            llegada=env.now
            tiempos_espera[nombre]=env.now
            with vacunacion.mesas_vacunacion.request() as mesas:
                yield mesas
                lista_cola=[key for key in list(estado_personas.keys()) if estado_personas[key]=='Cola']
                for i in range(MESAS_VACUNACION):
                    if len(lista_cola)>0:
                        persona_cola=lista_cola[0]
                        if vacunacion.mesas_libres_vacunacion(i):
                            if not persona_cola in personas_vacunacion:
                                MESAS_LIBRES_VACUNACION[i]='Ocupada'
                                personas_vacunacion[persona_cola]=i
                                inicio_vacunacion=env.now
                                print('💉 La: [%s] entra a vacunarse al hora %.2f MESA %s luego de esperar  %s minutos '%(persona_cola,env.now, i+1, env.now-tiempos_espera[persona_cola]))
                                tiempo_espera_final[persona_cola]=env.now-tiempos_espera[persona_cola]
                                yield env.process(vacunacion.proceso_vacunacion(persona_cola, tiempo_vacunacion,i))
                                print('Sale de vacunarse [%s] a la hora %.2f libre MESA %s se demoro %s minutos'%(persona_cola, env.now, i+1, env.now-inicio_vacunacion))
                                tiempo_vacunacion_final[persona_cola]=env.now-inicio_vacunacion
                        lista_cola.remove(persona_cola)
                lista_vacuna=[key for key in list(estado_personas.keys()) if estado_personas[key]=='Vacunado']
                for i in lista_vacuna:
                    if not i in personas_espera:
                        print('⌛ La: [%s] entra a la sala de espera al hora %.2f '%(i, env.now))
                        personas_espera[i]='espera'
                        yield env.process(vacunacion.proceso_esperar(i,tiempo_espera))
                        #print(' **** La: [%s] sale de sala de espera al hora %.2f '%(i, env.now))
                lista_espera=[key for key in list(estado_personas.keys()) if estado_personas[key]=='Espera_sintomas']
                for i in lista_espera:
                    if not i in personas_carnet:
                        print('📝 La: [%s] entra a recibir su carnet al hora %.2f '%(i, env.now))
                        personas_carnet[i]='carnet'
                        yield env.process(vacunacion.entrega_carnet(i,tiempo_certificado))
                        print('<<--- La: [%s] sale del recinto al hora %.2f '%(i, env.now))
        
    else:
        print('---> Genera [%s] hora %.2f. no realiza proceso ☠️'%(nombre,env.now))
        estado_personas[nombre]='No proceso'

# %% [markdown]
# ### Ejecutar Simulacion

# %%
def ejecutar_simulacion(env, mesas_vacunacion, intervalo_llegada, tiempo_vacunacion, tiempo_espera,tiempo_certificado):
    vacunacion = Vacunacion(env, mesas_vacunacion)
    i=0
    for j in range(COLA):
        env.process(llegada_personas(env,'Persona-%d'%(i+1), vacunacion,  tiempo_vacunacion, tiempo_espera, tiempo_certificado))
        i+=1
    while True:
        i+=1
        yield env.timeout(random.randint(intervalo_llegada-2, intervalo_llegada+2))
        env.process(llegada_personas(env,'Persona-%d'%(i), vacunacion,  tiempo_vacunacion, tiempo_espera, tiempo_certificado))
        
random.seed(77)
env= simpy.Environment()
env.process(ejecutar_simulacion(env, MESAS_VACUNACION,INTERVALO_LLEGADA, TIEMPO_VACUNACION, TIEMPO_ESPERAR_SINTOMAS, TIEMPO_CERTIFICADO))
env.run(until=TIEMPO_SIMULACION)
# Out:
# ---> Genera [Persona-1] a la cola hora 0.00.
# ---> Genera [Persona-2] a la cola hora 0.00.
# ---> Genera [Persona-3] hora 0.00. no realiza proceso ☠️
# ---> Genera [Persona-4] a la cola hora 0.00.
# ---> Genera [Persona-5] a la cola hora 0.00.
# ---> Genera [Persona-6] a la cola hora 0.00.
# ---> Genera [Persona-7] a la cola hora 0.00.
# ---> Genera [Persona-8] a la cola hora 0.00.
# ---> Genera [Persona-9] hora 0.00. no realiza proceso ☠️
# ---> Genera [Persona-10] a la cola hora 0.00.
# ❌❌❌ [Persona-10] acude al proceso pero no puede vacunarse   ❌❌❌
# 💉 La: [Persona-1] entra a vacunarse al hora 0.00 MESA 1 luego de esperar  0 minutos
# 💉 La: [Persona-2] entra a vacunarse al hora 0.00 MESA 2 luego de esperar  0 minutos
# 💉 La: [Persona-4] entra a vacunarse al hora 0.00 MESA 3 luego de esperar  0 minutos
# 💉 La: [Persona-5] entra a vacunarse al hora 0.00 MESA 4 luego de esperar  0 minutos
# ---> Genera [Persona-11] a la cola hora 5.00.
# Sale de vacunarse [Persona-2] a la hora 6.00 libre MESA 2 se demoro 6 minutos
# ⌛ La: [Persona-2] entra a la sala de espera al hora 6.00
# Sale de vacunarse [Persona-4] a la hora 6.00 libre MESA 3 se demoro 6 minutos
# ⌛ La: [Persona-4] entra a la sala de espera al hora 6.00
# Sale de vacunarse [Persona-1] a la hora 8.00 libre MESA 1 se demoro 8 minutos
# ⌛ La: [Persona-1] entra a la sala de espera al hora 8.00
# Sale de vacunarse [Persona-5] a la hora 9.00 libre MESA 4 se demoro 9 minutos
# ⌛ La: [Persona-5] entra a la sala de espera al hora 9.00
# ---> Genera [Persona-12] hora 11.00. no realiza proceso ☠️
# ---> Genera [Persona-13] a la cola hora 16.00.
# ---> Genera [Persona-14] a la cola hora 19.00.
# ---> Genera [Persona-15] a la cola hora 24.00.
# 📝 La: [Persona-2] entra a recibir su carnet al hora 26.00
# 📝 La: [Persona-4] entra a recibir su carnet al hora 26.00
# ---> Genera [Persona-16] hora 28.00. no realiza proceso ☠️
# 📝 La: [Persona-1] entra a recibir su carnet al hora 28.00
# <<--- La: [Persona-2] sale del recinto al hora 28.00
# <<--- La: [Persona-4] sale del recinto al hora 28.00
# 💉 La: [Persona-6] entra a vacunarse al hora 28.00 MESA 1 luego de esperar  28 minutos
# 💉 La: [Persona-7] entra a vacunarse al hora 28.00 MESA 2 luego de esperar  28 minutos
# 📝 La: [Persona-5] entra a recibir su carnet al hora 29.00
# <<--- La: [Persona-1] sale del recinto al hora 30.00
# 💉 La: [Persona-8] entra a vacunarse al hora 30.00 MESA 3 luego de esperar  30 minutos
# ---> Genera [Persona-17] a la cola hora 31.00.
# <<--- La: [Persona-5] sale del recinto al hora 31.00
# 💉 La: [Persona-11] entra a vacunarse al hora 31.00 MESA 4 luego de esperar  26 minutos
# Sale de vacunarse [Persona-6] a la hora 34.00 libre MESA 1 se demoro 6 minutos
# ⌛ La: [Persona-6] entra a la sala de espera al hora 34.00
# ---> Genera [Persona-18] hora 37.00. no realiza proceso ☠️
# Sale de vacunarse [Persona-7] a la hora 38.00 libre MESA 2 se demoro 10 minutos
# ⌛ La: [Persona-7] entra a la sala de espera al hora 38.00
# Sale de vacunarse [Persona-8] a la hora 39.00 libre MESA 3 se demoro 9 minutos
# ⌛ La: [Persona-8] entra a la sala de espera al hora 39.00
# ---> Genera [Persona-19] a la cola hora 40.00.
# Sale de vacunarse [Persona-11] a la hora 40.00 libre MESA 4 se demoro 9 minutos
# ⌛ La: [Persona-11] entra a la sala de espera al hora 40.00
# ---> Genera [Persona-20] hora 44.00. no realiza proceso ☠️
# ---> Genera [Persona-21] a la cola hora 47.00.
# ---> Genera [Persona-22] hora 54.00. no realiza proceso ☠️
# 📝 La: [Persona-6] entra a recibir su carnet al hora 54.00
# <<--- La: [Persona-6] sale del recinto al hora 56.00
# 💉 La: [Persona-13] entra a vacunarse al hora 56.00 MESA 1 luego de esperar  40 minutos
# 📝 La: [Persona-7] entra a recibir su carnet al hora 58.00
# 📝 La: [Persona-8] entra a recibir su carnet al hora 59.00
# 📝 La: [Persona-11] entra a recibir su carnet al hora 60.00
# <<--- La: [Persona-7] sale del recinto al hora 60.00
# 💉 La: [Persona-14] entra a vacunarse al hora 60.00 MESA 2 luego de esperar  41 minutos
# ---> Genera [Persona-23] hora 61.00. no realiza proceso ☠️
# <<--- La: [Persona-8] sale del recinto al hora 61.00
# 💉 La: [Persona-15] entra a vacunarse al hora 61.00 MESA 3 luego de esperar  37 minutos
# <<--- La: [Persona-11] sale del recinto al hora 62.00
# 💉 La: [Persona-17] entra a vacunarse al hora 62.00 MESA 4 luego de esperar  31 minutos
# Sale de vacunarse [Persona-13] a la hora 63.00 libre MESA 1 se demoro 7 minutos
# ⌛ La: [Persona-13] entra a la sala de espera al hora 63.00
# ---> Genera [Persona-24] a la cola hora 68.00.
# Sale de vacunarse [Persona-14] a la hora 68.00 libre MESA 2 se demoro 8 minutos
# ⌛ La: [Persona-14] entra a la sala de espera al hora 68.00
# Sale de vacunarse [Persona-15] a la hora 68.00 libre MESA 3 se demoro 7 minutos
# ⌛ La: [Persona-15] entra a la sala de espera al hora 68.00
# ---> Genera [Persona-25] a la cola hora 71.00.
# Sale de vacunarse [Persona-17] a la hora 71.00 libre MESA 4 se demoro 9 minutos
# ⌛ La: [Persona-17] entra a la sala de espera al hora 71.00
# ---> Genera [Persona-26] a la cola hora 78.00.
# ---> Genera [Persona-27] a la cola hora 82.00.
# 📝 La: [Persona-13] entra a recibir su carnet al hora 83.00
# <<--- La: [Persona-13] sale del recinto al hora 85.00
# 💉 La: [Persona-19] entra a vacunarse al hora 85.00 MESA 1 luego de esperar  45 minutos
# ---> Genera [Persona-28] hora 88.00. no realiza proceso ☠️
# 📝 La: [Persona-14] entra a recibir su carnet al hora 88.00
# 📝 La: [Persona-15] entra a recibir su carnet al hora 88.00
# <<--- La: [Persona-14] sale del recinto al hora 90.00
# <<--- La: [Persona-15] sale del recinto al hora 90.00
# 💉 La: [Persona-21] entra a vacunarse al hora 90.00 MESA 2 luego de esperar  43 minutos
# 💉 La: [Persona-24] entra a vacunarse al hora 90.00 MESA 3 luego de esperar  22 minutos
# 📝 La: [Persona-17] entra a recibir su carnet al hora 91.00
# Sale de vacunarse [Persona-19] a la hora 91.00 libre MESA 1 se demoro 6 minutos
# 💉 La: [Persona-25] entra a vacunarse al hora 91.00 MESA 4 luego de esperar  20 minutos
# <<--- La: [Persona-17] sale del recinto al hora 93.00
# ⌛ La: [Persona-19] entra a la sala de espera al hora 93.00
# ---> Genera [Persona-29] a la cola hora 94.00.
# Sale de vacunarse [Persona-21] a la hora 95.00 libre MESA 2 se demoro 5 minutos
# ⌛ La: [Persona-21] entra a la sala de espera al hora 95.00
# Sale de vacunarse [Persona-24] a la hora 95.00 libre MESA 3 se demoro 5 minutos
# ⌛ La: [Persona-24] entra a la sala de espera al hora 95.00
# ---> Genera [Persona-30] hora 97.00. no realiza proceso ☠️
# Sale de vacunarse [Persona-25] a la hora 99.00 libre MESA 4 se demoro 8 minutos
# ⌛ La: [Persona-25] entra a la sala de espera al hora 99.00
# ---> Genera [Persona-31] a la cola hora 103.00.
# ---> Genera [Persona-32] hora 108.00. no realiza proceso ☠️
# 📝 La: [Persona-19] entra a recibir su carnet al hora 113.00
# ---> Genera [Persona-33] a la cola hora 114.00.
# 📝 La: [Persona-21] entra a recibir su carnet al hora 115.00
# 📝 La: [Persona-24] entra a recibir su carnet al hora 115.00
# <<--- La: [Persona-19] sale del recinto al hora 115.00
# 💉 La: [Persona-26] entra a vacunarse al hora 115.00 MESA 1 luego de esperar  37 minutos
# <<--- La: [Persona-21] sale del recinto al hora 117.00
# <<--- La: [Persona-24] sale del recinto al hora 117.00
# 💉 La: [Persona-27] entra a vacunarse al hora 117.00 MESA 2 luego de esperar  35 minutos
# 💉 La: [Persona-29] entra a vacunarse al hora 117.00 MESA 3 luego de esperar  23 minutos
# 📝 La: [Persona-25] entra a recibir su carnet al hora 119.00
# ---> Genera [Persona-34] hora 120.00. no realiza proceso ☠️
# Sale de vacunarse [Persona-26] a la hora 120.00 libre MESA 1 se demoro 5 minutos
# 💉 La: [Persona-31] entra a vacunarse al hora 120.00 MESA 4 luego de esperar  17 minutos
# <<--- La: [Persona-25] sale del recinto al hora 121.00
# ⌛ La: [Persona-26] entra a la sala de espera al hora 121.00
# Sale de vacunarse [Persona-27] a la hora 123.00 libre MESA 2 se demoro 6 minutos
# ⌛ La: [Persona-27] entra a la sala de espera al hora 123.00
# Sale de vacunarse [Persona-29] a la hora 124.00 libre MESA 3 se demoro 7 minutos
# ⌛ La: [Persona-29] entra a la sala de espera al hora 124.00
# Sale de vacunarse [Persona-31] a la hora 125.00 libre MESA 4 se demoro 5 minutos
# ⌛ La: [Persona-31] entra a la sala de espera al hora 125.00
# ---> Genera [Persona-35] a la cola hora 127.00.
# ---> Genera [Persona-36] a la cola hora 133.00.
# ❌❌❌ [Persona-36] acude al proceso pero no puede vacunarse   ❌❌❌
# ---> Genera [Persona-37] a la cola hora 139.00.
# 📝 La: [Persona-26] entra a recibir su carnet al hora 141.00
# ---> Genera [Persona-38] a la cola hora 142.00.
# ❌❌❌ [Persona-38] acude al proceso pero no puede vacunarse   ❌❌❌
# 📝 La: [Persona-27] entra a recibir su carnet al hora 143.00
# <<--- La: [Persona-26] sale del recinto al hora 143.00
# 💉 La: [Persona-33] entra a vacunarse al hora 143.00 MESA 1 luego de esperar  29 minutos
# 📝 La: [Persona-29] entra a recibir su carnet al hora 144.00
# ---> Genera [Persona-39] a la cola hora 145.00.
# 📝 La: [Persona-31] entra a recibir su carnet al hora 145.00
# <<--- La: [Persona-27] sale del recinto al hora 145.00
# 💉 La: [Persona-35] entra a vacunarse al hora 145.00 MESA 2 luego de esperar  18 minutos
# <<--- La: [Persona-29] sale del recinto al hora 146.00
# 💉 La: [Persona-37] entra a vacunarse al hora 146.00 MESA 3 luego de esperar  7 minutos
# <<--- La: [Persona-31] sale del recinto al hora 147.00
# 💉 La: [Persona-39] entra a vacunarse al hora 147.00 MESA 4 luego de esperar  2 minutos
# ---> Genera [Persona-40] hora 148.00. no realiza proceso ☠️
# Sale de vacunarse [Persona-33] a la hora 149.00 libre MESA 1 se demoro 6 minutos
# ⌛ La: [Persona-33] entra a la sala de espera al hora 149.00
# Sale de vacunarse [Persona-35] a la hora 150.00 libre MESA 2 se demoro 5 minutos
# ⌛ La: [Persona-35] entra a la sala de espera al hora 150.00
# ---> Genera [Persona-41] a la cola hora 151.00.
# Sale de vacunarse [Persona-37] a la hora 154.00 libre MESA 3 se demoro 8 minutos
# ⌛ La: [Persona-37] entra a la sala de espera al hora 154.00
# ---> Genera [Persona-42] a la cola hora 155.00.
# Sale de vacunarse [Persona-39] a la hora 155.00 libre MESA 4 se demoro 8 minutos
# ⌛ La: [Persona-39] entra a la sala de espera al hora 155.00
# ---> Genera [Persona-43] hora 158.00. no realiza proceso ☠️
# ---> Genera [Persona-44] a la cola hora 162.00.
# ---> Genera [Persona-45] a la cola hora 165.00.
# 📝 La: [Persona-33] entra a recibir su carnet al hora 169.00
# 📝 La: [Persona-35] entra a recibir su carnet al hora 170.00
# <<--- La: [Persona-33] sale del recinto al hora 171.00
# 💉 La: [Persona-41] entra a vacunarse al hora 171.00 MESA 1 luego de esperar  20 minutos
# ---> Genera [Persona-46] a la cola hora 172.00.
# <<--- La: [Persona-35] sale del recinto al hora 172.00
# 💉 La: [Persona-42] entra a vacunarse al hora 172.00 MESA 2 luego de esperar  17 minutos
# 📝 La: [Persona-37] entra a recibir su carnet al hora 174.00
# 📝 La: [Persona-39] entra a recibir su carnet al hora 175.00
# <<--- La: [Persona-37] sale del recinto al hora 176.00
# 💉 La: [Persona-44] entra a vacunarse al hora 176.00 MESA 3 luego de esperar  14 minutos
# <<--- La: [Persona-39] sale del recinto al hora 177.00
# 💉 La: [Persona-45] entra a vacunarse al hora 177.00 MESA 4 luego de esperar  12 minutos
# ---> Genera [Persona-47] a la cola hora 179.00.
# Sale de vacunarse [Persona-41] a la hora 180.00 libre MESA 1 se demoro 9 minutos
# ⌛ La: [Persona-41] entra a la sala de espera al hora 180.00
# Sale de vacunarse [Persona-42] a la hora 181.00 libre MESA 2 se demoro 9 minutos
# ⌛ La: [Persona-42] entra a la sala de espera al hora 181.00
# ---> Genera [Persona-48] a la cola hora 182.00.
# Sale de vacunarse [Persona-44] a la hora 183.00 libre MESA 3 se demoro 7 minutos
# ⌛ La: [Persona-44] entra a la sala de espera al hora 183.00
# Sale de vacunarse [Persona-45] a la hora 186.00 libre MESA 4 se demoro 9 minutos
# ⌛ La: [Persona-45] entra a la sala de espera al hora 186.00
# ---> Genera [Persona-49] a la cola hora 188.00.
# ---> Genera [Persona-50] hora 193.00. no realiza proceso ☠️
# ---> Genera [Persona-51] a la cola hora 197.00.
# ❌❌❌ [Persona-51] acude al proceso pero no puede vacunarse   ❌❌❌
# 📝 La: [Persona-41] entra a recibir su carnet al hora 200.00
# 📝 La: [Persona-42] entra a recibir su carnet al hora 201.00
# <<--- La: [Persona-41] sale del recinto al hora 202.00
# 💉 La: [Persona-46] entra a vacunarse al hora 202.00 MESA 1 luego de esperar  30 minutos
# 📝 La: [Persona-44] entra a recibir su carnet al hora 203.00
# <<--- La: [Persona-42] sale del recinto al hora 203.00
# 💉 La: [Persona-47] entra a vacunarse al hora 203.00 MESA 2 luego de esperar  24 minutos
# ---> Genera [Persona-52] hora 204.00. no realiza proceso ☠️
# <<--- La: [Persona-44] sale del recinto al hora 205.00
# 💉 La: [Persona-48] entra a vacunarse al hora 205.00 MESA 3 luego de esperar  23 minutos
# 📝 La: [Persona-45] entra a recibir su carnet al hora 206.00
# Sale de vacunarse [Persona-46] a la hora 207.00 libre MESA 1 se demoro 5 minutos
# 💉 La: [Persona-49] entra a vacunarse al hora 207.00 MESA 4 luego de esperar  19 minutos
# ---> Genera [Persona-53] a la cola hora 208.00.
# Sale de vacunarse [Persona-47] a la hora 208.00 libre MESA 2 se demoro 5 minutos
# ⌛ La: [Persona-46] entra a la sala de espera al hora 208.00
# <<--- La: [Persona-45] sale del recinto al hora 208.00
# ⌛ La: [Persona-47] entra a la sala de espera al hora 208.00
# Sale de vacunarse [Persona-48] a la hora 210.00 libre MESA 3 se demoro 5 minutos
# ⌛ La: [Persona-48] entra a la sala de espera al hora 210.00
# ---> Genera [Persona-54] a la cola hora 211.00.
# ---> Genera [Persona-55] hora 214.00. no realiza proceso ☠️
# Sale de vacunarse [Persona-49] a la hora 217.00 libre MESA 4 se demoro 10 minutos
# ⌛ La: [Persona-49] entra a la sala de espera al hora 217.00
# ---> Genera [Persona-56] a la cola hora 218.00.
# ---> Genera [Persona-57] a la cola hora 224.00.
# 📝 La: [Persona-46] entra a recibir su carnet al hora 228.00
# 📝 La: [Persona-47] entra a recibir su carnet al hora 228.00
# ---> Genera [Persona-58] a la cola hora 230.00.
# 📝 La: [Persona-48] entra a recibir su carnet al hora 230.00
# <<--- La: [Persona-46] sale del recinto al hora 230.00
# <<--- La: [Persona-47] sale del recinto al hora 230.00
# 💉 La: [Persona-53] entra a vacunarse al hora 230.00 MESA 1 luego de esperar  22 minutos
# 💉 La: [Persona-54] entra a vacunarse al hora 230.00 MESA 2 luego de esperar  19 minutos
# <<--- La: [Persona-48] sale del recinto al hora 232.00
# 💉 La: [Persona-56] entra a vacunarse al hora 232.00 MESA 3 luego de esperar  14 minutos
# ---> Genera [Persona-59] a la cola hora 236.00.
# 📝 La: [Persona-49] entra a recibir su carnet al hora 237.00
# Sale de vacunarse [Persona-54] a la hora 237.00 libre MESA 2 se demoro 7 minutos
# 💉 La: [Persona-57] entra a vacunarse al hora 237.00 MESA 4 luego de esperar  13 minutos
# Sale de vacunarse [Persona-53] a la hora 238.00 libre MESA 1 se demoro 8 minutos
# ⌛ La: [Persona-53] entra a la sala de espera al hora 238.00
# ---> Genera [Persona-60] a la cola hora 239.00.
# Sale de vacunarse [Persona-56] a la hora 239.00 libre MESA 3 se demoro 7 minutos
# ⌛ La: [Persona-54] entra a la sala de espera al hora 239.00
# <<--- La: [Persona-49] sale del recinto al hora 239.00
# 💉 La: [Persona-58] entra a vacunarse al hora 239.00 MESA 2 luego de esperar  9 minutos
# ---> Genera [Persona-61] a la cola hora 243.00.
# Sale de vacunarse [Persona-57] a la hora 244.00 libre MESA 4 se demoro 7 minutos
# ⌛ La: [Persona-56] entra a la sala de espera al hora 244.00
# Sale de vacunarse [Persona-58] a la hora 246.00 libre MESA 2 se demoro 7 minutos
# 💉 La: [Persona-59] entra a vacunarse al hora 246.00 MESA 3 luego de esperar  10 minutos
# ---> Genera [Persona-62] a la cola hora 249.00.
# ---> Genera [Persona-63] a la cola hora 256.00.
# Sale de vacunarse [Persona-59] a la hora 256.00 libre MESA 3 se demoro 10 minutos
# 💉 La: [Persona-60] entra a vacunarse al hora 256.00 MESA 4 luego de esperar  17 minutos
# 📝 La: [Persona-53] entra a recibir su carnet al hora 258.00
# 📝 La: [Persona-54] entra a recibir su carnet al hora 259.00
# <<--- La: [Persona-53] sale del recinto al hora 260.00
# 💉 La: [Persona-61] entra a vacunarse al hora 260.00 MESA 2 luego de esperar  17 minutos
# <<--- La: [Persona-54] sale del recinto al hora 261.00
# 💉 La: [Persona-62] entra a vacunarse al hora 261.00 MESA 3 luego de esperar  12 minutos
# ---> Genera [Persona-64] hora 263.00. no realiza proceso ☠️
# ⌛ La: [Persona-57] entra a la sala de espera al hora 264.00
# Sale de vacunarse [Persona-60] a la hora 264.00 libre MESA 4 se demoro 8 minutos
# ⌛ La: [Persona-58] entra a la sala de espera al hora 264.00
# ---> Genera [Persona-65] a la cola hora 268.00.
# Sale de vacunarse [Persona-61] a la hora 270.00 libre MESA 2 se demoro 10 minutos
# 💉 La: [Persona-63] entra a vacunarse al hora 270.00 MESA 4 luego de esperar  14 minutos
# Sale de vacunarse [Persona-62] a la hora 270.00 libre MESA 3 se demoro 9 minutos
# ⌛ La: [Persona-59] entra a la sala de espera al hora 270.00
# ---> Genera [Persona-66] a la cola hora 273.00.
# Sale de vacunarse [Persona-63] a la hora 276.00 libre MESA 4 se demoro 6 minutos
# ⌛ La: [Persona-60] entra a la sala de espera al hora 276.00
# ---> Genera [Persona-67] a la cola hora 277.00.
# ---> Genera [Persona-68] a la cola hora 280.00.
# 📝 La: [Persona-56] entra a recibir su carnet al hora 284.00
# 📝 La: [Persona-57] entra a recibir su carnet al hora 284.00
# <<--- La: [Persona-56] sale del recinto al hora 286.00
# 📝 La: [Persona-58] entra a recibir su carnet al hora 286.00
# <<--- La: [Persona-57] sale del recinto al hora 286.00
# 💉 La: [Persona-65] entra a vacunarse al hora 286.00 MESA 1 luego de esperar  18 minutos
# ---> Genera [Persona-69] hora 287.00. no realiza proceso ☠️
# <<--- La: [Persona-58] sale del recinto al hora 288.00
# 💉 La: [Persona-66] entra a vacunarse al hora 288.00 MESA 2 luego de esperar  15 minutos
# ⌛ La: [Persona-61] entra a la sala de espera al hora 290.00
# ---> Genera [Persona-70] a la cola hora 294.00.
# ⌛ La: [Persona-62] entra a la sala de espera al hora 296.00
# Sale de vacunarse [Persona-65] a la hora 296.00 libre MESA 1 se demoro 10 minutos
# 💉 La: [Persona-67] entra a vacunarse al hora 296.00 MESA 3 luego de esperar  19 minutos
# ---> Genera [Persona-71] a la cola hora 297.00.
# Sale de vacunarse [Persona-66] a la hora 297.00 libre MESA 2 se demoro 9 minutos
# 💉 La: [Persona-68] entra a vacunarse al hora 297.00 MESA 4 luego de esperar  17 minutos

# %% [markdown]
# ### Resultados

# %%
vacunados=0
proceso=0
no_atendidos=0
no_proceso=0
cola=0
for key in estado_personas:
    if estado_personas[key]=='Carnet': vacunados+=1
    if estado_personas[key]=='No proceso': no_proceso+=1
    if estado_personas[key]=='No califica': no_atendidos+=1
    if estado_personas[key]=='Cola': cola+=1
    if estado_personas[key]=='Carnet' or estado_personas[key]=='No califica' or estado_personas[key]=='Cola':  proceso+=1
print('-'*70,'\n* Total personas Generadas: ', len(estado_personas))
print('* Personas que asistieron al proceso: ', proceso)
print('* Personas que no asistieron al proceso: ', no_proceso)
print('* Personas que no pudieron vacunarse: ', no_atendidos)
print('* Personas que se vacunaron: ', vacunados)
print('* Personas que aun se encuentran en cola: ', cola)
print('* Tiempo promedio espera en la cola a ser atendido: ',sum(list(tiempo_espera_final.values()))/len(tiempo_espera_final),'\n','-'*70)
# Out:
# ----------------------------------------------------------------------
# * Total personas Generadas:  71
# * Personas que asistieron al proceso:  45
# * Personas que no asistieron al proceso:  19
# * Personas que no pudieron vacunarse:  4
# * Personas que se vacunaron:  37
# * Personas que aun se encuentran en cola:  4
# * Tiempo promedio espera en la cola a ser atendido:  20.304347826086957
#  ----------------------------------------------------------------------

# %% [markdown]
# ### Grafico tiempo espera en la cola

# %%
import matplotlib.pyplot as plt

promedio={}
for i in list(tiempo_espera_final.keys()):
    #print(i.split('-'))
    promedio[i.split('-')[1]]=tiempo_espera_final[i]


plt.figure(figsize = (15,7))
plt.plot(list(promedio.keys()),list(promedio.values()),'*-b')
plt.xticks(list(promedio.keys())[::5])
plt.axhline(y=sum(list(tiempo_espera_final.values()))/len(tiempo_espera_final), xmin=0.0, xmax=1,color='red',linestyle="--")

plt.title('Tiempo de espera a ser atendidos')
plt.xlabel('Personas')
plt.ylabel('Tiempo minutos')
plt.legend(['Tiempo Espera','Tiempo Promedio'])

# %% [markdown]
# ### Grafico tiempo vacunacion de las personas

# %%
promedio_vacunacion={}
for i in list(tiempo_vacunacion_final.keys()):
    #print(i.split('-'))
    promedio_vacunacion[int(i.split('-')[1])]=tiempo_vacunacion_final[i]
promedio_vacunacion=dict(sorted(promedio_vacunacion.items()))

plt.figure(figsize = (15,7))
plt.plot(promedio_vacunacion.keys(), promedio_vacunacion.values(),'*-', color='#18A1F2')
plt.axhline(y=sum(list(tiempo_vacunacion_final.values()))/len(tiempo_vacunacion_final), xmin=0.0, xmax=1,color='#9318F2',linestyle="--")
plt.title('Tiempo Vacunacion')
plt.xlabel('Personas')
plt.ylabel('Tiempo')
plt.legend(['Espera por persona', 'Promedio'])

# %% [markdown]
# ### Grafico personas total generadas

# %%
x = [1,2,3,4,5]

tags = ['Total','Proceso', 'Vacunados','No proceso', 'No Vacunados']

fig, ax = plt.subplots(figsize=(10,5))
bar1 = ax.bar(x[0], len(estado_personas), 0.25, label='Total', color="#007CC2")
bar2 = ax.bar(x[1], proceso, 0.25, label='Proceso', color="#9318F2")
bar3= ax.bar(x[2], vacunados, 0.25, label='Vacunados', color="#1AE57E")
bar4 = ax.bar(x[3], no_proceso, 0.25, label='No proceso', color='#E21AE5')
bar5= ax.bar(x[4], no_atendidos, 0.25, label='No Vacunados', color="#D70006")


ax.set_ylabel('Cantidad de personas')
ax.set_title('Personas')
ax.set_xticks(x)
ax.set_xticklabels(tags)
ax.legend(loc="upper right")

plt.show()
