# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
total=pd.read_csv('total_vacunas.csv')
total.head()
date=total['fecha']

# %%
plt.figure(figsize=(15,8))
plt.scatter(total['fecha'],total['primera_dosis'], color="b")
plt.scatter(total['fecha'],total['segunda_dosis'], color="r")
plt.xticks(total.fecha[::5].tolist())
# Out:
# ([<matplotlib.axis.XTick at 0x142c42af208>,
#   <matplotlib.axis.XTick at 0x142c3961308>,
#   <matplotlib.axis.XTick at 0x142c2fadbc8>,
#   <matplotlib.axis.XTick at 0x142c456d088>,
#   <matplotlib.axis.XTick at 0x142c456d808>,
#   <matplotlib.axis.XTick at 0x142c456df88>,
#   <matplotlib.axis.XTick at 0x142c4572808>,
#   <matplotlib.axis.XTick at 0x142c4572fc8>,
#   <matplotlib.axis.XTick at 0x142c4576a08>,
#   <matplotlib.axis.XTick at 0x142c4579508>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
total['fecha'] = pd.to_datetime(total['fecha'])
total['fecha']=pd.to_datetime(total['fecha'].astype(str), format='%Y-%m-%d')

# %%
from datetime import datetime,timedelta
import datetime as dt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
total=pd.read_csv('total_vacunas.csv')

total['fecha'] = total['fecha'].map(lambda x : (datetime.strptime(x, '%d/%m/%Y') - datetime.strptime("01/01/2021", '%d/%m/%Y')).days)
x=total['fecha'].values.reshape(-1,1)
y=total['segunda_dosis'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
model2=LinearRegression()
model2.fit(X_train, y_train)
y_pred=model2.predict(x)

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(x)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)
pol_pred=pol_reg.predict(poly_reg.fit_transform(x))

# %%
plt.figure(figsize = (15,5))
def graficar():
    plt.plot(x, y,'.g')
    plt.plot(x, pol_pred,  '-', linewidth = 3, color='r')
    plt.title('Regresión Polinomial')
    plt.xlabel('Dias')
    plt.ylabel('Vacunas')
    plt.legend(['Segunda Dosis', 'Prediccion'])
    plt.show()
    return

graficar()

# %%
plt.figure(figsize=(15,8))
plt.scatter(total['fecha'],total['segunda_dosis'])
plt.plot(total['fecha'],y_pred,'-r')

# %%
# calcular personas unicas con las 2 vacunos, restar vacunas primera dosis con los de la segunda dosis, con eso modelo lineal
# polinomial vacunacion ambas dosis

# %% [markdown]
# # Prediccion Total infectados en una fecha, fecha a vacunarse todos

# %%
x=total['fecha'].values.reshape(-1,1)
y=total['dosis_total'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
poly_reg = PolynomialFeatures(degree=3)
X_poly = poly_reg.fit_transform(x)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)
pol_pred=pol_reg.predict(poly_reg.fit_transform(x))

# %%
plt.figure(figsize = (15,5))

plt.plot(x, y,'.g')
plt.plot(x, pol_pred,  '-', linewidth = 3, color='r')
plt.title('Regresión Polinomial')
plt.xlabel('Dias')
plt.ylabel('Vacunas')
plt.legend(['Dosis Aplicadas', 'Prediccion'])
plt.show()

# %%
nueva_fecha='09/10/2021'
fec =  (datetime.strptime(nueva_fecha, '%d/%m/%Y') - datetime.strptime("01/01/2021", '%d/%m/%Y')).days
prediccion_fecha= pol_reg.predict( poly_reg.fit_transform([[fec]]))
prediccion_fecha
# Out:
# array([[30250869.17685021]])

# %%
nueva_fecha='15/08/2022'
fec =  (datetime.strptime(nueva_fecha, '%d/%m/%Y') - datetime.strptime("01/01/2021", '%d/%m/%Y')).days
prediccion_fecha= pol_reg.predict( poly_reg.fit_transform([[fec]]))
prediccion_fecha
# Out:
# array([[3.81775195e+08]])

# %%
# en la anterior seccion solo analizamos un dia especifica en el proximo anio 
# realizamos otra grafica donde se analisa los datos desde fin de anio hasta el final de abril del 2022 fecha tentiva que
# todos se vacunaran 
import numpy as np

fechas=np.arange(365, 485, dtype=int)
prediccion_fecha= pol_reg.predict( poly_reg.fit_transform(fechas.reshape(-1, 1)))

# %%
plt.plot(fechas,prediccion_fecha)
